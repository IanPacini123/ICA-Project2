# %%
train_dir = "../emotion_detection/fer_2013/train" # Directory containing the training data
test_dir = "../emotion_detection/fer_2013/test"  # Directory containing the validation data

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    width_shift_range = 0.1,        # Randomly shift the width of images by up to 10%
    height_shift_range = 0.1,       # Randomly shift the height of images by up to 10%
    horizontal_flip = True,         # Flip images horizontally at random
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = train_dir,           # Directory containing the training data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "training"              # Uses the training subset of the data
)

validation_generator = validation_datagen.flow_from_directory(
    directory = test_dir,            # Directory containing the validation data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "validation"            # Uses the validation subset of the data
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Sequential
import tensorflow as tf 

# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
# Add a batch normalization layer
model.add(BatchNormalization())
# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a second batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a third convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a third batch normalization layer
model.add(BatchNormalization())
# Add a fourth convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a fourth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a fifth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a fifth batch normalization layer
model.add(BatchNormalization())
# Add a sixth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a sixth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 256 neurons and relu activation function
model.add(Dense(256, activation='relu'))
# Add a seventh batch normalization layer
model.add(BatchNormalization())
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add a dense layer with 7 neurons (one for each class) and softmax activation function
model.add(Dense(7, activation='softmax'))

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.legacy.Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
from PIL import Image
from keras.preprocessing.image import load_img
from tensorflow.keras.callbacks import ModelCheckpoint
import scipy

# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\Ianpa\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Ianpa\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 359/359 [==============================] - ETA: 0s - loss: 2.8133 - accuracy: 0.1823
# Epoch 1: val_accuracy improved from -inf to 0.24721, saving model to model_weights.h5
# 359/359 [==============================] - 83s 228ms/step - loss: 2.8133 - accuracy: 0.1823 - val_loss: 1.9087 - val_accuracy: 0.2472
# Epoch 2/50
# 359/359 [==============================] - ETA: 0s - loss: 2.4136 - accuracy: 0.2265
# Epoch 2: val_accuracy improved from 0.24721 to 0.34218, saving model to model_weights.h5
# 359/359 [==============================] - 80s 222ms/step - loss: 2.4136 - accuracy: 0.2265 - val_loss: 1.7321 - val_accuracy: 0.3422
# Epoch 3/50
# 359/359 [==============================] - ETA: 0s - loss: 2.2064 - accuracy: 0.2663
# Epoch 3: val_accuracy improved from 0.34218 to 0.36941, saving model to model_weights.h5
# 359/359 [==============================] - 80s 224ms/step - loss: 2.2064 - accuracy: 0.2663 - val_loss: 1.7266 - val_accuracy: 0.3694
# Epoch 4/50
# 359/359 [==============================] - ETA: 0s - loss: 2.0769 - accuracy: 0.2956
# Epoch 4: val_accuracy did not improve from 0.36941
# 359/359 [==============================] - 81s 226ms/step - loss: 2.0769 - accuracy: 0.2956 - val_loss: 1.8242 - val_accuracy: 0.3408
# Epoch 5/50
# 359/359 [==============================] - ETA: 0s - loss: 1.9835 - accuracy: 0.3117
# Epoch 5: val_accuracy improved from 0.36941 to 0.42179, saving model to model_weights.h5
# 359/359 [==============================] - 76s 210ms/step - loss: 1.9835 - accuracy: 0.3117 - val_loss: 1.5515 - val_accuracy: 0.4218
# Epoch 6/50
# 359/359 [==============================] - ETA: 0s - loss: 1.8792 - accuracy: 0.3379
# Epoch 6: val_accuracy improved from 0.42179 to 0.44832, saving model to model_weights.h5
# 359/359 [==============================] - 76s 211ms/step - loss: 1.8792 - accuracy: 0.3379 - val_loss: 1.4777 - val_accuracy: 0.4483
# Epoch 7/50
# 359/359 [==============================] - ETA: 0s - loss: 1.8189 - accuracy: 0.3594
# Epoch 7: val_accuracy improved from 0.44832 to 0.46369, saving model to model_weights.h5
# 359/359 [==============================] - 75s 209ms/step - loss: 1.8189 - accuracy: 0.3594 - val_loss: 1.4623 - val_accuracy: 0.4637
# Epoch 8/50
# 359/359 [==============================] - ETA: 0s - loss: 1.7356 - accuracy: 0.3750
# Epoch 8: val_accuracy did not improve from 0.46369
# 359/359 [==============================] - 75s 209ms/step - loss: 1.7356 - accuracy: 0.3750 - val_loss: 1.4372 - val_accuracy: 0.4546
# Epoch 9/50
# 359/359 [==============================] - ETA: 0s - loss: 1.6771 - accuracy: 0.3926
# Epoch 9: val_accuracy improved from 0.46369 to 0.48254, saving model to model_weights.h5
# 359/359 [==============================] - 75s 209ms/step - loss: 1.6771 - accuracy: 0.3926 - val_loss: 1.3838 - val_accuracy: 0.4825
# Epoch 10/50
# 359/359 [==============================] - ETA: 0s - loss: 1.6237 - accuracy: 0.4071
# Epoch 10: val_accuracy improved from 0.48254 to 0.50070, saving model to model_weights.h5
# 359/359 [==============================] - 75s 209ms/step - loss: 1.6237 - accuracy: 0.4071 - val_loss: 1.3438 - val_accuracy: 0.5007
# Epoch 11/50
# 359/359 [==============================] - ETA: 0s - loss: 1.5653 - accuracy: 0.4249
# Epoch 11: val_accuracy improved from 0.50070 to 0.52095, saving model to model_weights.h5
# 359/359 [==============================] - 75s 209ms/step - loss: 1.5653 - accuracy: 0.4249 - val_loss: 1.2905 - val_accuracy: 0.5209
# Epoch 12/50
# 359/359 [==============================] - ETA: 0s - loss: 1.5132 - accuracy: 0.4402
# Epoch 12: val_accuracy improved from 0.52095 to 0.53631, saving model to model_weights.h5
# 359/359 [==============================] - 75s 209ms/step - loss: 1.5132 - accuracy: 0.4402 - val_loss: 1.2379 - val_accuracy: 0.5363
# Epoch 13/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4810 - accuracy: 0.4456
# Epoch 13: val_accuracy improved from 0.53631 to 0.53841, saving model to model_weights.h5
# 359/359 [==============================] - 75s 209ms/step - loss: 1.4810 - accuracy: 0.4456 - val_loss: 1.2265 - val_accuracy: 0.5384
# Epoch 14/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4199 - accuracy: 0.4721
# Epoch 14: val_accuracy improved from 0.53841 to 0.55936, saving model to model_weights.h5
# 359/359 [==============================] - 75s 209ms/step - loss: 1.4199 - accuracy: 0.4721 - val_loss: 1.2039 - val_accuracy: 0.5594
# Epoch 15/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4046 - accuracy: 0.4728
# Epoch 15: val_accuracy did not improve from 0.55936
# 359/359 [==============================] - 75s 209ms/step - loss: 1.4046 - accuracy: 0.4728 - val_loss: 1.2188 - val_accuracy: 0.5426
# Epoch 16/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3700 - accuracy: 0.4825
# Epoch 16: val_accuracy did not improve from 0.55936
# 359/359 [==============================] - 75s 209ms/step - loss: 1.3700 - accuracy: 0.4825 - val_loss: 1.2051 - val_accuracy: 0.5496
# Epoch 17/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3473 - accuracy: 0.4916
# Epoch 17: val_accuracy improved from 0.55936 to 0.57612, saving model to model_weights.h5
# 359/359 [==============================] - 75s 209ms/step - loss: 1.3473 - accuracy: 0.4916 - val_loss: 1.1668 - val_accuracy: 0.5761
# Epoch 18/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3152 - accuracy: 0.5072
# Epoch 18: val_accuracy did not improve from 0.57612
# 359/359 [==============================] - 75s 209ms/step - loss: 1.3152 - accuracy: 0.5072 - val_loss: 1.1552 - val_accuracy: 0.5712
# Epoch 19/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2904 - accuracy: 0.5158
# Epoch 19: val_accuracy improved from 0.57612 to 0.58170, saving model to model_weights.h5
# 359/359 [==============================] - 75s 208ms/step - loss: 1.2904 - accuracy: 0.5158 - val_loss: 1.1419 - val_accuracy: 0.5817
# Epoch 20/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2685 - accuracy: 0.5234
# Epoch 20: val_accuracy did not improve from 0.58170
# 359/359 [==============================] - 75s 208ms/step - loss: 1.2685 - accuracy: 0.5234 - val_loss: 1.1202 - val_accuracy: 0.5719
# Epoch 21/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2508 - accuracy: 0.5281
# Epoch 21: val_accuracy did not improve from 0.58170
# 359/359 [==============================] - 74s 207ms/step - loss: 1.2508 - accuracy: 0.5281 - val_loss: 1.1540 - val_accuracy: 0.5705
# Epoch 22/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2359 - accuracy: 0.5365
# Epoch 22: val_accuracy did not improve from 0.58170
# 359/359 [==============================] - 74s 207ms/step - loss: 1.2359 - accuracy: 0.5365 - val_loss: 1.1315 - val_accuracy: 0.5691
# Epoch 23/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2144 - accuracy: 0.5409
# Epoch 23: val_accuracy improved from 0.58170 to 0.58310, saving model to model_weights.h5
# 359/359 [==============================] - 74s 207ms/step - loss: 1.2144 - accuracy: 0.5409 - val_loss: 1.1011 - val_accuracy: 0.5831
# Epoch 24/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2052 - accuracy: 0.5451
# Epoch 24: val_accuracy improved from 0.58310 to 0.58939, saving model to model_weights.h5
# 359/359 [==============================] - 75s 209ms/step - loss: 1.2052 - accuracy: 0.5451 - val_loss: 1.0945 - val_accuracy: 0.5894
# Epoch 25/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1840 - accuracy: 0.5526
# Epoch 25: val_accuracy did not improve from 0.58939
# 359/359 [==============================] - 75s 207ms/step - loss: 1.1840 - accuracy: 0.5526 - val_loss: 1.0851 - val_accuracy: 0.5859
# Epoch 26/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1735 - accuracy: 0.5579
# Epoch 26: val_accuracy improved from 0.58939 to 0.59218, saving model to model_weights.h5
# 359/359 [==============================] - 75s 208ms/step - loss: 1.1735 - accuracy: 0.5579 - val_loss: 1.0747 - val_accuracy: 0.5922
# Epoch 27/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1601 - accuracy: 0.5671
# Epoch 27: val_accuracy improved from 0.59218 to 0.60265, saving model to model_weights.h5
# 359/359 [==============================] - 75s 208ms/step - loss: 1.1601 - accuracy: 0.5671 - val_loss: 1.0482 - val_accuracy: 0.6027
# Epoch 28/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1485 - accuracy: 0.5672
# Epoch 28: val_accuracy improved from 0.60265 to 0.60475, saving model to model_weights.h5
# 359/359 [==============================] - 75s 208ms/step - loss: 1.1485 - accuracy: 0.5672 - val_loss: 1.0442 - val_accuracy: 0.6047
# Epoch 29/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1389 - accuracy: 0.5727
# Epoch 29: val_accuracy improved from 0.60475 to 0.60615, saving model to model_weights.h5
# 359/359 [==============================] - 75s 209ms/step - loss: 1.1389 - accuracy: 0.5727 - val_loss: 1.0498 - val_accuracy: 0.6061
# Epoch 30/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1273 - accuracy: 0.5775
# Epoch 30: val_accuracy did not improve from 0.60615
# 359/359 [==============================] - 75s 209ms/step - loss: 1.1273 - accuracy: 0.5775 - val_loss: 1.0603 - val_accuracy: 0.6013
# Epoch 31/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1169 - accuracy: 0.5793
# Epoch 31: val_accuracy improved from 0.60615 to 0.61732, saving model to model_weights.h5
# 359/359 [==============================] - 75s 208ms/step - loss: 1.1169 - accuracy: 0.5793 - val_loss: 1.0409 - val_accuracy: 0.6173
# Epoch 32/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1170 - accuracy: 0.5794
# Epoch 32: val_accuracy did not improve from 0.61732
# 359/359 [==============================] - 75s 208ms/step - loss: 1.1170 - accuracy: 0.5794 - val_loss: 1.0542 - val_accuracy: 0.6027
# Epoch 33/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1040 - accuracy: 0.5876
# Epoch 33: val_accuracy improved from 0.61732 to 0.62221, saving model to model_weights.h5
# 359/359 [==============================] - 75s 208ms/step - loss: 1.1040 - accuracy: 0.5876 - val_loss: 1.0057 - val_accuracy: 0.6222
# Epoch 34/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0886 - accuracy: 0.5895
# Epoch 34: val_accuracy improved from 0.62221 to 0.62291, saving model to model_weights.h5
# 359/359 [==============================] - 75s 209ms/step - loss: 1.0886 - accuracy: 0.5895 - val_loss: 1.0167 - val_accuracy: 0.6229
# Epoch 35/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0828 - accuracy: 0.5953
# Epoch 35: val_accuracy improved from 0.62291 to 0.62500, saving model to model_weights.h5
# 359/359 [==============================] - 75s 208ms/step - loss: 1.0828 - accuracy: 0.5953 - val_loss: 1.0334 - val_accuracy: 0.6250
# Epoch 36/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0706 - accuracy: 0.5947
# Epoch 36: val_accuracy did not improve from 0.62500
# 359/359 [==============================] - 75s 208ms/step - loss: 1.0706 - accuracy: 0.5947 - val_loss: 1.0098 - val_accuracy: 0.6215
# Epoch 37/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0672 - accuracy: 0.5997
# Epoch 37: val_accuracy improved from 0.62500 to 0.63827, saving model to model_weights.h5
# 359/359 [==============================] - 75s 208ms/step - loss: 1.0672 - accuracy: 0.5997 - val_loss: 1.0028 - val_accuracy: 0.6383
# Epoch 38/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0556 - accuracy: 0.6034
# Epoch 38: val_accuracy did not improve from 0.63827
# 359/359 [==============================] - 74s 207ms/step - loss: 1.0556 - accuracy: 0.6034 - val_loss: 0.9943 - val_accuracy: 0.6243
# Epoch 39/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0473 - accuracy: 0.6048
# Epoch 39: val_accuracy did not improve from 0.63827
# 359/359 [==============================] - 74s 207ms/step - loss: 1.0473 - accuracy: 0.6048 - val_loss: 1.0220 - val_accuracy: 0.6166
# Epoch 40/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0479 - accuracy: 0.6079
# Epoch 40: val_accuracy improved from 0.63827 to 0.64385, saving model to model_weights.h5
# 359/359 [==============================] - 75s 208ms/step - loss: 1.0479 - accuracy: 0.6079 - val_loss: 0.9705 - val_accuracy: 0.6439
# Epoch 41/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0351 - accuracy: 0.6086
# Epoch 41: val_accuracy improved from 0.64385 to 0.64874, saving model to model_weights.h5
# 359/359 [==============================] - 82s 228ms/step - loss: 1.0351 - accuracy: 0.6086 - val_loss: 0.9642 - val_accuracy: 0.6487
# Epoch 42/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0222 - accuracy: 0.6123
# Epoch 42: val_accuracy did not improve from 0.64874
# 359/359 [==============================] - 80s 222ms/step - loss: 1.0222 - accuracy: 0.6123 - val_loss: 0.9797 - val_accuracy: 0.6383
# Epoch 43/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0251 - accuracy: 0.6159
# Epoch 43: val_accuracy did not improve from 0.64874
# 359/359 [==============================] - 78s 216ms/step - loss: 1.0251 - accuracy: 0.6159 - val_loss: 0.9634 - val_accuracy: 0.6390
# Epoch 44/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0123 - accuracy: 0.6181
# Epoch 44: val_accuracy did not improve from 0.64874
# 359/359 [==============================] - 79s 219ms/step - loss: 1.0123 - accuracy: 0.6181 - val_loss: 0.9630 - val_accuracy: 0.6439
# Epoch 45/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0058 - accuracy: 0.6207
# Epoch 45: val_accuracy did not improve from 0.64874
# 359/359 [==============================] - 77s 213ms/step - loss: 1.0058 - accuracy: 0.6207 - val_loss: 0.9667 - val_accuracy: 0.6432
# Epoch 46/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0032 - accuracy: 0.6214
# Epoch 46: val_accuracy improved from 0.64874 to 0.65852, saving model to model_weights.h5
# 359/359 [==============================] - 77s 214ms/step - loss: 1.0032 - accuracy: 0.6214 - val_loss: 0.9313 - val_accuracy: 0.6585
# Epoch 47/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9912 - accuracy: 0.6297
# Epoch 47: val_accuracy did not improve from 0.65852
# 359/359 [==============================] - 77s 214ms/step - loss: 0.9912 - accuracy: 0.6297 - val_loss: 0.9300 - val_accuracy: 0.6564
# Epoch 48/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9825 - accuracy: 0.6315
# Epoch 48: val_accuracy did not improve from 0.65852
# 359/359 [==============================] - 77s 213ms/step - loss: 0.9825 - accuracy: 0.6315 - val_loss: 0.9865 - val_accuracy: 0.6411
# Epoch 49/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9812 - accuracy: 0.6338
# Epoch 49: val_accuracy did not improve from 0.65852
# 359/359 [==============================] - 80s 222ms/step - loss: 0.9812 - accuracy: 0.6338 - val_loss: 0.9601 - val_accuracy: 0.6376
# Epoch 50/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9730 - accuracy: 0.6343
# Epoch 50: val_accuracy did not improve from 0.65852
# 359/359 [==============================] - 78s 218ms/step - loss: 0.9730 - accuracy: 0.6343 - val_loss: 0.9588 - val_accuracy: 0.6466
